# %%
import requests
from bs4 import BeautifulSoup # beautifulsoup4
import pandas as pd
import lxml
import csv
import time
import random
import math

# %%
BASE_URL = "https://www.lamudi.com.ph/buy/metro-manila"
property_data = []

# %%
cities = [
    'quezon-city', 
    # 'makati', 'taguig', 
    # 'manila', 'mandaluyong', 'pasay', 
    # 'marikina', 'muntinlupa', 'san-juan-5', 
    # 'las-pinas', 'paranaque', 'pasig',
    ]

# Mapping URL city names to correct names
city_name_mapping = {
    "san-juan-5": "san juan",
    "las-pinas": "las piñas",
    "paranaque": "parañaque",  # Handle special characters
}

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

column_names = [
    "price", "category", "bedrooms", "bathrooms", "building_size", 
    "condominium_name", "sku", "geo_location", "furnished_status", 
    "title", "address", "short_description", "url"
]



for city in cities:
    correct_city_name = city_name_mapping.get(city, city.replace("-", " "))

    page = 1  # Start from the first page
    max_pages = 1
    while page <= max_pages:
        listings_url = f"{BASE_URL}/{city}/condo/?page={page}"

        print(f"Fetching: {listings_url}")

        try:
            response = requests.get(listings_url, headers=headers, timeout=10)
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            print(f"Error fetching {listings_url}: {e}")
            break  # Stop fetching for this city if an error occurs

        soup = BeautifulSoup(response.text, "lxml")

        # Find all property listings on the page
        listing_containers = soup.find_all("div", class_="ListingCell-AllInfo")

        if not listing_containers:
            print(f"No more listings found on page {page}. Moving to next city.")
            break  # Exit loop when no more listings are found (last page reached)

        for listing in listing_containers:
            property_info = {key: None for key in column_names}

            # Extract data attributes
            property_info["price"] = listing.get("data-price", None)
            property_info["category"] = listing.get("data-category", None)
            property_info["bedrooms"] = listing.get("data-bedrooms", None)
            property_info["bathrooms"] = listing.get("data-bathrooms", None)
            property_info["building_size"] = listing.get("data-building_size", None)
            property_info["condominium_name"] = listing.get("data-condominiumname", None)
            property_info["sku"] = listing.get("data-sku", None)
            property_info["geo_location"] = listing.get("data-geo-point", None)
            property_info["furnished_status"] = listing.get("data-furnished", None)

            # Extract title
            title = listing.find("h3", class_="ListingCell-KeyInfo-title")
            property_info["title"] = title.text.strip() if title else None

            # Extract address
            address = listing.find("span", class_="ListingCell-KeyInfo-address-text")
            property_info["address"] = address.text.strip() if address else None

            # **City Filtering - Ensure listing is for the correct city**
            if property_info["address"]:
                address_lower = property_info["address"].lower()
                if correct_city_name.lower() not in address_lower:  # Check against correct name
                    print(f"Skipping listing: {property_info['title']} - Address does not match {correct_city_name}")
                    continue  # Skip incorrect listings

            # Extract short description
            description = listing.find("div", class_="ListingCell-shortDescription")
            property_info["short_description"] = description.text.strip() if description else None

            # Extract link
            link = listing.find("a", class_="js-listing-link")
            property_info["url"] = f"https://www.lamudi.com.ph{link['href']}" if link else None

            if property_info not in property_data:
                property_data.append(property_info)
            else:
                print(f"{property_info['address']} already in list. currently at city:{correct_city_name} and page{page}")

        print(f"Scraped {len(listing_containers)} listings from page {page}.")
        
        # Random delay to avoid overwhelming the server
        delay = random.uniform(3, 5)
        print(f"Waiting {delay:.2f} seconds before the next request...")
        time.sleep(delay)

        count_element = soup.find("span", class_="CountTitle-number")
        if count_element:
            total_listings = int(count_element.text.strip().replace(',',''))  # Extract and convert to int
            max_pages = min(math.ceil(total_listings / 30), 50) 
        
        page += 1  # Move to the next page



print(f"\nTotal properties scraped: {len(property_data)}")
for element in property_data[:5]:  # Print first 5 for testing
    print(f"{element}\n")
# Out:
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=1
# Scraped 30 listings from page 1.
# Waiting 3.68 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=2
# Scraped 30 listings from page 2.
# Waiting 3.42 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=3
# Nagkaisang Nayon, Quezon City already in list. currently at city:quezon city and page3
# Scraped 30 listings from page 3.
# Waiting 4.76 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=4
# Scraped 30 listings from page 4.
# Waiting 3.91 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=5
# Scraped 30 listings from page 5.
# Waiting 3.09 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=6
# Scraped 30 listings from page 6.
# Waiting 4.75 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=7
# Scraped 30 listings from page 7.
# Waiting 4.74 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=8
# Scraped 30 listings from page 8.
# Waiting 3.03 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=9
# Scraped 30 listings from page 9.
# Waiting 4.98 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=10
# Scraped 30 listings from page 10.
# Waiting 4.09 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=11
# Scraped 30 listings from page 11.
# Waiting 4.01 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=12
# Scraped 30 listings from page 12.
# Waiting 4.23 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=13
# Katipunan, Quezon City already in list. currently at city:quezon city and page13
# Scraped 30 listings from page 13.
# Waiting 3.09 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=14
# Scraped 30 listings from page 14.
# Waiting 4.83 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=15
# Scraped 30 listings from page 15.
# Waiting 4.64 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=16
# Marilag, Quezon City already in list. currently at city:quezon city and page16
# Scraped 30 listings from page 16.
# Waiting 3.92 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=17
# Loyola Heights, Quezon City already in list. currently at city:quezon city and page17
# Balingasa, Quezon City already in list. currently at city:quezon city and page17
# Scraped 30 listings from page 17.
# Waiting 3.36 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=18
# Scraped 30 listings from page 18.
# Waiting 4.82 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=19
# Scraped 30 listings from page 19.
# Waiting 4.62 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=20
# Horseshoe, Quezon City already in list. currently at city:quezon city and page20
# Loyola Heights, Quezon City already in list. currently at city:quezon city and page20
# Katipunan, Quezon City already in list. currently at city:quezon city and page20
# Kamuning, Quezon City already in list. currently at city:quezon city and page20
# Scraped 30 listings from page 20.
# Waiting 4.25 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=21
# New Manila, Quezon City already in list. currently at city:quezon city and page21
# Scraped 30 listings from page 21.
# Waiting 4.48 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=22
# Scraped 30 listings from page 22.
# Waiting 3.44 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=23
# West Triangle, Quezon City already in list. currently at city:quezon city and page23
# Bagumbayan, Quezon City already in list. currently at city:quezon city and page23
# Ugong Norte, Quezon City already in list. currently at city:quezon city and page23
# Ugong Norte, Quezon City already in list. currently at city:quezon city and page23
# Scraped 30 listings from page 23.
# Waiting 4.83 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=24
# North Avenue, Quezon City already in list. currently at city:quezon city and page24
# Bagong Pag-Asa, Quezon City already in list. currently at city:quezon city and page24
# Scraped 30 listings from page 24.
# Waiting 3.48 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=25
# Scraped 30 listings from page 25.
# Waiting 4.07 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=26
# North Avenue, Quezon City already in list. currently at city:quezon city and page26
# Ugong Norte, Quezon City already in list. currently at city:quezon city and page26
# Loyola Heights, Quezon City already in list. currently at city:quezon city and page26
# Valencia, Quezon City already in list. currently at city:quezon city and page26
# Loyola Heights, Quezon City already in list. currently at city:quezon city and page26
# Loyola Heights, Quezon City already in list. currently at city:quezon city and page26
# Scraped 30 listings from page 26.
# Waiting 4.58 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=27
# Scraped 30 listings from page 27.
# Waiting 3.71 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=28
# Tandang Sora, Quezon City already in list. currently at city:quezon city and page28
# Bagong Pag-Asa, Quezon City already in list. currently at city:quezon city and page28
# Scraped 30 listings from page 28.
# Waiting 3.29 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=29
# Novaliches, Quezon City already in list. currently at city:quezon city and page29
# Balingasa, Quezon City already in list. currently at city:quezon city and page29
# Diliman, Quezon City already in list. currently at city:quezon city and page29
# Diliman, Quezon City already in list. currently at city:quezon city and page29
# Quezon City already in list. currently at city:quezon city and page29
# North Avenue, Quezon City already in list. currently at city:quezon city and page29
# Balingasa, Quezon City already in list. currently at city:quezon city and page29
# Eastwood City, Quezon City already in list. currently at city:quezon city and page29
# Scraped 30 listings from page 29.
# Waiting 3.61 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=30
# Scraped 30 listings from page 30.
# Waiting 3.68 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=31
# Scraped 30 listings from page 31.
# Waiting 3.33 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=32
# Scraped 30 listings from page 32.
# Waiting 4.55 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=33
# Culiat, Quezon City already in list. currently at city:quezon city and page33
# Scraped 30 listings from page 33.
# Waiting 4.35 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=34
# Quezon Avenue, Quezon City already in list. currently at city:quezon city and page34
# Bagong Pag-Asa, Quezon City already in list. currently at city:quezon city and page34
# Bagong Pag-Asa, Quezon City already in list. currently at city:quezon city and page34
# Scraped 30 listings from page 34.
# Waiting 3.15 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=35
# Valencia, Quezon City already in list. currently at city:quezon city and page35
# Loyola Heights, Quezon City already in list. currently at city:quezon city and page35
# Katipunan, Quezon City already in list. currently at city:quezon city and page35
# Cubao, Quezon City already in list. currently at city:quezon city and page35
# Loyola Heights, Quezon City already in list. currently at city:quezon city and page35
# Valencia, Quezon City already in list. currently at city:quezon city and page35
# Kaunlaran, Quezon City already in list. currently at city:quezon city and page35
# Aurora, Quezon City already in list. currently at city:quezon city and page35
# Bagumbayan, Quezon City already in list. currently at city:quezon city and page35
# Project 4, Quezon City already in list. currently at city:quezon city and page35
# Project 4, Quezon City already in list. currently at city:quezon city and page35
# Project 4, Quezon City already in list. currently at city:quezon city and page35
# Scraped 30 listings from page 35.
# Waiting 4.12 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=36
# Scraped 30 listings from page 36.
# Waiting 4.47 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=37
# Scraped 30 listings from page 37.
# Waiting 4.62 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=38
# Loyola Heights, Quezon City already in list. currently at city:quezon city and page38
# Scraped 30 listings from page 38.
# Waiting 3.99 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=39
# Scraped 30 listings from page 39.
# Waiting 3.38 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=40
# South Triangle, Quezon City already in list. currently at city:quezon city and page40
# Bagumbayan, Quezon City already in list. currently at city:quezon city and page40
# Santo Cristo, Quezon City already in list. currently at city:quezon city and page40
# Scraped 30 listings from page 40.
# Waiting 3.80 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=41
# Scraped 30 listings from page 41.
# Waiting 4.27 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=42
# Scraped 30 listings from page 42.
# Waiting 4.01 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=43
# Scraped 30 listings from page 43.
# Waiting 4.22 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=44
# Scraped 30 listings from page 44.
# Waiting 3.14 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=45
# Scraped 30 listings from page 45.
# Waiting 4.75 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=46
# New Manila, Quezon City already in list. currently at city:quezon city and page46
# Valencia, Quezon City already in list. currently at city:quezon city and page46
# Obrero, Quezon City already in list. currently at city:quezon city and page46
# Cubao, Quezon City already in list. currently at city:quezon city and page46
# Scraped 30 listings from page 46.
# Waiting 3.16 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=47
# Panay Avenue, Quezon City already in list. currently at city:quezon city and page47
# South Triangle, Quezon City already in list. currently at city:quezon city and page47
# Diliman, Quezon City already in list. currently at city:quezon city and page47
# Libis, Quezon City already in list. currently at city:quezon city and page47
# Balingasa, Quezon City already in list. currently at city:quezon city and page47
# West Triangle, Quezon City already in list. currently at city:quezon city and page47
# Bagumbayan, Quezon City already in list. currently at city:quezon city and page47
# Fairview, Quezon City already in list. currently at city:quezon city and page47
# Fairview, Quezon City already in list. currently at city:quezon city and page47
# Eastwood City, Quezon City already in list. currently at city:quezon city and page47
# Eastwood City, Quezon City already in list. currently at city:quezon city and page47
# Ugong Norte, Quezon City already in list. currently at city:quezon city and page47
# New Manila, Quezon City already in list. currently at city:quezon city and page47
# Batasan Hills, Quezon City already in list. currently at city:quezon city and page47
# Panay Avenue, Quezon City already in list. currently at city:quezon city and page47
# West Triangle, Quezon City already in list. currently at city:quezon city and page47
# Cubao, Quezon City already in list. currently at city:quezon city and page47
# Scraped 30 listings from page 47.
# Waiting 4.88 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=48
# Scraped 30 listings from page 48.
# Waiting 3.78 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=49
# Scraped 30 listings from page 49.
# Waiting 3.42 seconds before the next request...
# Fetching: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=50
# Loyola Heights, Quezon City already in list. currently at city:quezon city and page50
# Balingasa, Quezon City already in list. currently at city:quezon city and page50
# Scraped 30 listings from page 50.
# Waiting 3.50 seconds before the next request...
#
# Total properties scraped: 1425
# {'price': '3757084', 'category': 'condo', 'bedrooms': '1', 'bathrooms': '1', 'building_size': '22', 'condominium_name': 'Calle Centrale', 'sku': 'CD673EAE3357E3CPH', 'geo_location': '[121.081903,14.605396]', 'furnished_status': '270', 'title': 'Calle Centrale QC Pre-Selling Condo: Below Market Value and No Downpayment!', 'address': 'Bagumbayan, Quezon City', 'short_description': 'Don’t miss out on this limited-time offer! Secure your unit condo with our Special Promo Offer designed to fit your budget :\n\n\n  0% Downpayment! (No spot Down payment!)\n  20% Spread over 57 months (for as low as ₱16k-18k/month!)\n  80% turnover balance thru bank or in-house financing\n\n\n*INQUIRE TODAY FOR AVAILABLE UNITS AND SAMPLE COMPUTATION!*\n\nExplore Your Options: Typical Units Available at Calle Central!\n\n  Studio Units (22-22.65 SQM)\n  Other units are also available\n\n\nExpected turnover: 2029\nIntroducing Calle Centrale\nAn exciting new pre-selling condominium project strategically located in the thriving C5 corridor, near Eastwood City and Bridgetowne Estate.\n\nThis prime location offers residents unparalleled access to top business hubs, lifestyle centers, and major highways, promising high potential for value appreciation and ultimate convenience.\n\nLive at the heart of the action with top malls like Eastwood, The Podium, and Opus just around the corner. Enjoy next-level convenience in a home designed for your lifestyle.\n\nRedefined Luxury: More than just a home-it\'s a community that celebrates life\'s simple joys, authenticity, and sustainability, perfect for multi-generational families, end-users, and investors.\n\nWhy Invest in Calle Industria, Quezon City Condos?\n1. Strategic Location: Near major CBDs-BGC (10.4KM), Pasig (4.7KM), Ortigas (5.5KM), and Makati (12.2KM).\n2. Great Value: Competitive prices compared to other cities for maximum investment returns.\n3. Top Connectivity: 7 of 13 metro train stations plus future MRT-7 and LRT-MRT links.\n4. Highly Urbanized City: DTI\'s "Most Competitive Highly Urbanized City" for 3 years running.\n\nAmenities:\n• Fitness Gym\n• Yoga Area\n• Jogging Path\n• Pool
in closet) with 2 toilet & bath.\n\n*With two (2) parking space near elevator (located at Level-2)\n\n*Corner unit with two (2) balcony.\n\n*82 square meters\n\n*With 3 inverter air condition units (1HP & 2HP wall type and 2HP split type).\n\n*Fully interior unit with built-in cabinets, LED lights, CCTV, granite tiles and high end fittings.\n\n*Unit located at Atrium floor (with garden) and high-level floor (42th floor).\n\n*Clean title and updated tax.\n\n*CGT by seller other transfer fees shoulder by buyer.\n\n*CASH or Bank Financing only.\n\n-RFS, owner move-in to new House & Lot.\n\nFOR INQUIRIES AND VIEWING\nPaolo Barotilla\nThe Lead Realty\nUnder REBL 5055', 'url': 'https://www.lamudi.com.phhttps://www.lamudi.com.ph/buy/metro-manila/quezon-city/zinnia-south-tower-3-bedroom-quezon-city-dmci-cond-17380342723/'}
#
# {'price': '16000000', 'category': 'condo', 'bedrooms': '3', 'bathrooms': '2', 'building_size': '84.5', 'condominium_name': 'The Crestmont', 'sku': 'CD679758068B22FPH', 'geo_location': '[121.03282,14.63977]', 'furnished_status': None, 'title': '3BR Condo With Tandem Parking Crestmont DMCI Near Solaire QC', 'address': 'Panay Avenue, Quezon City', 'short_description': 'DMCI Homes Proudly Develop The Crestmont Residences.\nAlong Panay Avenue Quezon Ave. 100 meters away from Edsa MRT.\nBeside McDonald Quezon Ave Edsa QC.\nFronting Eton Centris Mall.\nNear Solaire QC, trinoma.\n\nResale/Pasalo!\n\ntransfer of ownership Process Direct DMCI homes.\n\n3bedroom corner unit 84 sqm 20th-floor ortigas view with tandem parking 30sqm basement 3.\n\nCompletion date: June 2025\n\nThe current market value is 17.6M\nNow Selling 16M\nSave as much as 1.6M\n\nCash out to owner: \xa05,157,246\nBalance from DMCI \xa0:10,842,754\nThe commencing date is June 2025 through a bank loan\nor in-house financing.', 'url': 'https://www.lamudi.com.phhttps://www.lamudi.com.ph/buy/metro-manila/quezon-city/3br-condo-with-tandem-parking-crestmont-dmci-near-173797171874/'}

# %% [markdown]
# Price
# Property Type - House, Condo
# Bedrooms
# Bathrooms
# Building Size
# Land Size
# Subdivision Name
# Fully Furnished
# Foreclosures
# Title
# Link

# %%
#Convert to Pandas DF
df = pd.DataFrame(property_data)
df.head(10)
# Out:
#       price category bedrooms bathrooms building_size  \
# 0   3757084    condo        1         1            22
# 1   3737860    condo        1         1            22
# 2   3764292    condo        1         1            22
# 3  12500000    condo        3         2            82
# 4  16000000    condo        3         2          84.5
# 5   2800000    condo        0         1            20
# 6  10800000    condo        1         1            51
# 7   8155000    condo        1         1          37.5
# 8   6301200    condo        2         1          35.6
# 9   7455240    condo        2         1            39
#
#            condominium_name                sku  \
# 0            Calle Centrale  CD673EAE3357E3CPH
# 1            Calle Centrale  CD673EAD9B4C741PH
# 2            Calle Centrale  CD6735CC7707C77PH
# 3             Zinnia Towers  CD67984C6062788PH
# 4             The Crestmont  CD679758068B22FPH
